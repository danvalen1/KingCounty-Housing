# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import CustomModule as cm

df = cm.LoadHousingData(['price', 'date', 'bedrooms','bathrooms','sqft_living','grade','sqft_lot', 'yr_built'], clean=True)
# Out:
# /Users/danielvalenzuela/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
cm.PlotScatter(df['df'], 'sqft_per_occupant', 'price', hue='grade')

# %%
cm.CorrHeatmap(df['train_set'])
# Out:
# /Users/danielvalenzuela/Documents/Flatiron/Repositories/phase2/KingCounty-Housing/CustomModule.py:236: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   return fig.show()

# %%
cm.Resid(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-8f04277f89c2> in <module>()
# ----> 1 cm.Resid(df)
#
# /Users/danielvalenzuela/Documents/Flatiron/Repositories/phase2/KingCounty-Housing/CustomModule.py in Resid(df)
#     254     visualizer = ResidualsPlot(model)
#     255
# --> 256     visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
#     257     visualizer.score(X_test, y_test)  # Evaluate the model on the test data
#     258
#
# /Users/danielvalenzuela/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/yellowbrick/regressor/residuals.py in fit(self, X, y, **kwargs)
#     579         """
#     580         # fit the underlying model to the data
# --> 581         super(ResidualsPlot, self).fit(X, y, **kwargs)
#     582         self.score(X, y, train=True)
#     583         return self
#
# ...

# %%
cm.Linreg(df['train_set'])

# %%
cm.PlotScatter(df['df'], 'sqft_lot', 'price', hue='urban')
